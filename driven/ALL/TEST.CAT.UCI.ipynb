# %%
# !nvidia-smi
# Out:
# Tue Jul  6 12:07:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  On   | 00000000:04:00.0 Off |                  N/A |
# | 23%   30C    P8     7W / 250W |      1MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  On   | 00000000:05:00.0 Off |                  N/A |
# | 23%   27C    P8     8W / 250W |      1MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 108...  On   | 00000000:08:00.0 Off |                  N/A |
# | 23%   30C    P8     8W / 250W |      1MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 108...  On   | 00000000:84:00.0 Off |                  N/A |
# | 21%   29C    P8    10W / 250W |      1MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  GeForce GTX 108...  On   | 00000000:85:00.0 Off |                  N/A |
# | 21%   28C    P8    10W / 250W |      1MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   5  GeForce GTX 108...  On   | 00000000:88:00.0 Off |                  N/A |
# | 21%   25C    P8     9W / 250W |      1MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   6  GeForce GTX 108...  On   | 00000000:89:00.0 Off |                  N/A |
# | 21%   28C    P8     9W / 250W |      1MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#!pip3 install -U scikit-learn==0.24.1
#!pip3 install -U scikit-learn==0.20 (final)
# Out:
# Requirement already satisfied: scikit-learn==0.20 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (0.20.0)
# Requirement already satisfied: scipy>=0.13.3 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from scikit-learn==0.20) (1.5.4)
# Requirement already satisfied: numpy>=1.8.2 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from scikit-learn==0.20) (1.19.5)
# WARNING: You are using pip version 20.3.3; however, version 21.1.3 is available.
# You should consider upgrading via the '/homedtic/jrafael/anaconda3/envs/deeplung/bin/python -m pip install --upgrade pip' command.

# %%
#!pip3 install -U tensorflow==1.14.0
#!pip3 install -U h5py==2.10.0
#!pip install attention
# Out:
# Requirement already satisfied: attention in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (4.0)
# Requirement already satisfied: numpy>=1.18.1 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from attention) (1.19.5)
# Collecting tensorflow>=2.1
#   Using cached tensorflow-2.5.0-cp36-cp36m-manylinux2010_x86_64.whl (454.3 MB)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (2.5.0.dev2021032900)
# Requirement already satisfied: flatbuffers~=1.12.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (1.12)
# Requirement already satisfied: termcolor~=1.1.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (1.12.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (3.3.0)
# Requirement already satisfied: wheel~=0.35 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (0.36.2)
# Requirement already satisfied: absl-py~=0.10 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (0.12.0)
# Requirement already satisfied: gast==0.4.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (0.4.0)
# Requirement already satisfied: grpcio~=1.34.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (1.34.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (1.6.3)
# Requirement already satisfied: google-pasta~=0.2 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorflow>=2.1->attention) (3.17.2)
# Collecting h5py~=3.1.0
#   Using cached h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
# Requirement already satisfied: cached-property in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow>=2.1->attention) (1.5.2)
# Collecting tensorboard~=2.5
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# Requirement already satisfied: markdown>=2.6.8 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (2.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (57.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (2.25.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.1->attention) (1.30.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1->attention) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1->attention) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1->attention) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.1->attention) (1.3.0)
# Requirement already satisfied: importlib-metadata in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.1->attention) (4.5.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow>=2.1->attention) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1->attention) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1->attention) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1->attention) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.1->attention) (1.26.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.1->attention) (3.1.1)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: dataclasses in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from werkzeug>=0.11.15->tensorboard~=2.5->tensorflow>=2.1->attention) (0.8)
# Requirement already satisfied: zipp>=0.5 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.1->attention) (3.4.1)
# Installing collected packages: tensorflow-estimator, tensorboard, h5py, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.10.0
#     Uninstalling h5py-2.10.0:
#       Successfully uninstalled h5py-2.10.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 1.3.4 requires tensorboard!=2.5.0,>=2.2.0, but you have tensorboard 2.5.0 which is incompatible.
# pytorch-forecasting 0.9.0 requires scikit-learn<0.25,>=0.23, but you have scikit-learn 0.20.0 which is incompatible.
# Successfully installed h5py-3.1.0 tensorboard-2.5.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0
# WARNING: You are using pip version 20.3.3; however, version 21.1.3 is available.
# You should consider upgrading via the '/homedtic/jrafael/anaconda3/envs/deeplung/bin/python -m pip install --upgrade pip' command.

# %%
#print(tf.__version__)
#print(keras.__version__)
# Out:
# 2.5.0
# 2.5.0

# %%
#!pip uninstall -y tensorflow
#!/homedtic/jrafael/anaconda3/bin/conda uninstall -y tensorflow
#!pip3 install pywrap
#!pip3 install tensorflow
# Out:
# WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)
# Found existing installation: tensorflow 2.5.0
# Uninstalling tensorflow-2.5.0:
#   Successfully uninstalled tensorflow-2.5.0

# %%
#!pip3 install -U scikit-learn==0.20.0
# Out:
# WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)
# WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)
# Collecting scikit-learn==0.20.0
#   Using cached scikit_learn-0.20.0-cp36-cp36m-manylinux1_x86_64.whl (5.3 MB)
# Requirement already satisfied: numpy>=1.8.2 in /homedtic/jrafael/.local/lib/python3.6/site-packages (from scikit-learn==0.20.0) (1.19.5)
# Requirement already satisfied: scipy>=0.13.3 in /homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages (from scikit-learn==0.20.0) (1.5.4)
# WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)
#     Found existing installation: scikit-learn 0.24.2
#     Uninstalling scikit-learn-0.24.2:
#       Successfully uninstalled scikit-learn-0.24.2
# WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-forecasting 0.9.0 requires scikit-learn<0.25,>=0.23, but you have scikit-learn 0.20.0 which is incompatible.
# Successfully installed scikit-learn-0.20.0
# WARNING: Ignoring invalid distribution -pacy (/homedtic/jrafael/anaconda3/envs/deeplung/lib/python3.6/site-packages)

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import sklearn
sklearn.__version__
# Out:
# '0.20.0'

# %%
import os
import time
import requests
import pandas as pd
import numpy as np
from pickle import load
from datetime import timedelta
import matplotlib.pyplot as plt

# %%
from sodapy import Socrata
from sklearn.metrics import mean_absolute_error, mean_squared_error#,mean_absolute_percentage_error

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Lambda, Dot, Activation, Concatenate, Layer
from attention import Attention

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
#LOAD

# %%
#Merge, remove null and na imputation

# %%
today = "2021-04-09"

# %%
dfInRisk = pd.read_csv("data_flow/inrisk_CAT_" + today + ".csv")

for i,col in enumerate(dfInRisk.columns):
    if i==0:
        dfInRisk[col] = pd.to_datetime(dfInRisk[col])
    else:
        dfInRisk[col] = pd.to_numeric(dfInRisk[col])

dfInRisk.sort_values("date",ascending=True, inplace=True)
dfInRisk["risk_BCN"] = dfInRisk["inrisk_08"]
dfInRisk["risk_GI"] = dfInRisk["inrisk_17"]
dfInRisk["risk_TAR"] = dfInRisk["inrisk_43"]
dfInRisk["risk_LLE"] = dfInRisk["inrisk_25"]
dfInRisk = dfInRisk[["date","risk_BCN","risk_GI","risk_LLE","risk_TAR"]]

print(dfInRisk.shape)
print(dfInRisk.columns)
print(dfInRisk["date"].iloc[-5:])
print(dfInRisk["date"].iloc[0])
# Out:
# (398, 5)
# Index(['date', 'risk_BCN', 'risk_GI', 'risk_LLE', 'risk_TAR'], dtype='object')
# 393   2021-03-15
# 394   2021-03-16
# 395   2021-03-17
# 396   2021-03-18
# 397   2021-03-19
# Name: date, dtype: datetime64[ns]
# 2020-02-15 00:00:00

# %%
# calculate cases by computing the mean of the last 7 days reported cases
cols = dfInRisk.columns
print(cols)
for k in range(1,len(cols)):
    zn = []
    for i in range(dfInRisk.shape[0]):
        acc = 0
        for j in range(7):
            if i-j>=0:
                acc += dfInRisk.iloc[i-j,k]
        zn.append(acc/7)

    dfInRisk[cols[k] + "_7"] = zn
    
    #plot
    #plt.figure(figsize=(10,4))    
    #ax = plt.subplot(1,2,1)
    #dfInRisk[["mean"]].plot(ax=ax)
    #ax = plt.subplot(1,2,2)
    #dfInRisk[["mean_7"]].plot(ax=ax)    
    #plt.show()
    #break
    
dfInRisk = dfInRisk[["date","risk_BCN_7","risk_GI_7","risk_LLE_7","risk_TAR_7"]]
dfInRisk
# Out:
# Index(['date', 'risk_BCN', 'risk_GI', 'risk_LLE', 'risk_TAR'], dtype='object')
#           date  risk_BCN_7   risk_GI_7  risk_LLE_7  risk_TAR_7
# 0   2020-02-15    0.072949    0.151855    0.043482    0.102327
# 1   2020-02-16    0.143009    0.275563    0.075502    0.181203
# 2   2020-02-17    0.209083    0.381742    0.108660    0.260290
# 3   2020-02-18    0.279912    0.493185    0.143284    0.343318
# 4   2020-02-19    0.354539    0.602402    0.179170    0.428768
# ..         ...         ...         ...         ...         ...
# 393 2021-03-15  233.210782  139.892285   68.357402  106.818405
# 394 2021-03-16  236.485094  141.624650   68.076668  107.634371
# 395 2021-03-17  239.198669  142.814572   67.596189  107.492742
# 396 2021-03-18  243.290157  144.225753   67.145308  108.536820
# 397 2021-03-19  247.997908  151.417122   68.221038  111.205435
#
# [398 rows x 5 columns]

# %%
dfCases = pd.read_csv("data_flow/cases_CAT_" + today + ".csv")
dfCases["date"] = pd.to_datetime(dfCases["date"])
dfCases.sort_values("date",ascending=True, inplace=True)

#Aggregate
dfCases["new_cases"] = np.nansum(dfCases[['new_cases_BCN', 'new_cases_GI', 
                                          'new_cases_TAR',"new_cases_LLE"]],axis=1)
dfCases = dfCases[["date","new_cases","new_cases_BCN","new_cases_GI","new_cases_TAR","new_cases_LLE"]]
dfCases["total_cases"] = np.cumsum(dfCases["new_cases"].values)
print(dfCases.shape,dfCases.columns)
# Out:
# (464, 7) Index(['date', 'new_cases', 'new_cases_BCN', 'new_cases_GI', 'new_cases_TAR',
#        'new_cases_LLE', 'total_cases'],
#       dtype='object')

# %%
cols = dfCases.columns
for k in range(1,len(cols)):
    zn = []
    for i in range(dfCases.shape[0]):
        acc = 0
        for j in range(7):
            if i-j>=0:
                acc += dfCases.iloc[i-j,k]
        zn.append(acc/7)

    dfCases[cols[k] + "_7"] = zn

dfCases
# Out:
#           date  new_cases  new_cases_BCN  new_cases_GI  new_cases_TAR  \
# 0   2020-01-01          0              0             0              0
# 1   2020-01-02          0              0             0              0
# 2   2020-01-03          1              0             0              0
# 3   2020-01-04          0              0             0              0
# 4   2020-01-05          0              0             0              0
# ..         ...        ...            ...           ...            ...
# 459 2021-04-04        339            204            43             41
# 460 2021-04-05        217            130            29             22
# 461 2021-04-06        171            127            34              4
# 462 2021-04-07          0              0             0              0
# 463 2021-04-08          0              0             0              0
#
#      new_cases_LLE  total_cases  new_cases_7  new_cases_BCN_7  new_cases_GI_7  \
# 0                0            0     0.000000         0.000000        0.000000
# 1                0            0     0.000000         0.000000        0.000000
# 2                1            1     0.142857         0.000000        0.000000
# 3                0            1     0.142857         0.000000        0.000000
# 4                0            1     0.142857         0.000000        0.000000
# ..             ...          ...          ...              ...             ...
# 459             51       537934   900.714286       641.428571      103.857143
# 460             36       538151   721.857143       504.428571       85.571429
# 461              6       538322   560.857143       384.857143       67.857143
# 462              0       538322   391.857143       264.285714       46.428571
# 463              0       538322   243.857143       159.571429       30.142857
#
#      new_cases_TAR_7  new_cases_LLE_7  total_cases_7
# 0           0.000000         0.000000       0.000000
# 1           0.000000         0.000000       0.000000
# 2           0.000000         0.142857       0.142857
# 3           0.000000         0.142857       0.285714
# 4           0.000000         0.142857       0.428571
# ..               ...              ...            ...
# 459        52.571429       102.857143  536045.142857
# 460        46.714286        85.142857  536767.000000
# 461        38.857143        69.285714  537327.857143
# 462        29.142857        52.000000  537719.714286
# 463        20.714286        33.428571  537963.571429
#
# [464 rows x 13 columns]

# %%
dfUCI = pd.read_csv("data_flow/UCI_CAT_TOTAL" + today +".csv")
print(dfUCI.columns)
dfUCI.plot()
dfUCI["date"] = pd.to_datetime(dfUCI["date"])
# Out:
# Index(['date', 'uci'], dtype='object')

# %%
cols = dfUCI.columns
for k in range(1,len(cols)):
    zn = []
    for i in range(dfUCI.shape[0]):
        acc = 0
        for j in range(7):
            if i-j>=0:
                acc += dfUCI.iloc[i-j,k]
        zn.append(acc/7)

    dfUCI[cols[k] + "_7"] = zn

dfUCI
# Out:
#           date  uci      uci_7
# 0   2020-03-01    0   0.000000
# 1   2020-03-02    0   0.000000
# 2   2020-03-03    0   0.000000
# 3   2020-03-04    0   0.000000
# 4   2020-03-05    0   0.000000
# ..         ...  ...        ...
# 774 2022-04-14   19  54.857143
# 775 2022-04-15   17  48.714286
# 776 2022-04-16   21  43.857143
# 777 2022-04-17   15  40.142857
# 778 2022-04-18    0  29.714286
#
# [779 rows x 3 columns]

# %%
#Forecasting predictions!!

# %%
modelNames = [
    "best_model_uci_HOSP.base",
    "best_model_uci_HOSP.base.mov",
    #"best_model_uci_CAT_7to21ahead_1_ocu_fixed.mean7.mov",
]

# %%
#Get cls

# %%
preds_all = []
for cls in modelNames:

    fname = cls
    print("\n"+fname)


    #Read data
    dfAll = pd.merge(dfCases[["date","new_cases","total_cases","new_cases_7",
                             "new_cases_GI_7","new_cases_LLE_7","new_cases_BCN_7","new_cases_TAR_7"]],
                     dfInRisk[["date","risk_BCN_7","risk_GI_7","risk_LLE_7","risk_TAR_7"]], 
                     how="left",on="date")
    dfAll["date"] = pd.to_datetime(dfAll["date"])

    #Merge with UCI
    dfAll = pd.merge(dfAll, dfUCI, how="left",on="date")
    dfAll["date"] = pd.to_datetime(dfAll["date"])
    dfAll["uci"] = pd.to_numeric(dfAll["uci"])
    dfAll["uci_7"] = pd.to_numeric(dfAll["uci_7"])

    dfAll["date"] = pd.to_datetime(dfAll["date"])

    #Remove days without mobility index 
    dfAll = dfAll.iloc[121:]

    #Remove last day 
    dfAll = dfAll.iloc[:-20]

    dfAll.reset_index(inplace=True, drop=True)
    
    #Na inputation
    dfAll.interpolate(method='linear', limit_direction='forward', axis=0, inplace=True, order=2)


    dateIni = str(dfAll.iloc[0]["date"])[:-9]
    dateFi = str(dfAll.iloc[-1]["date"])[:-9]
    print(dateIni, dateFi)

    #Convert data to format (rows,timepoints,features)
    if fname == "best_model_uci_HOSP.base":
        cols = ['uci']
    elif fname == "best_model_uci_HOSP.base.mov":
        cols = ['risk_BCN_7','risk_GI_7','risk_LLE_7','risk_TAR_7','uci']
        
    print(cols)
    ncols=len(cols)
    res = series_to_supervised(dfAll.loc[:,cols].values,7,7)   
    THR = int(res.shape[0]*0.1)
    print(res.shape, THR)
    
    #Patition train/test
    data_X = res.iloc[:,:(7*ncols)].values.reshape(-1,7,ncols)
    real_all = res.iloc[:,[(7*ncols)+(ncols*i) for i in range(7)]].values.reshape(-1,7)
    data_y = res.iloc[:,[((len(cols)*7)+len(cols))+(len(cols)*i)-1 for i in range(7)]].values.reshape(-1,7)
    #print(data_X[353,:,0])

    # normalize features
    scalers_X = []
    for i in range(data_X.shape[-1]):
        print(fname + "_scaler_tr_X_" + str(i)+'.pkl')
        scaler = load(open("models/"+ fname + "_scaler_tr_X_" + str(i)+'.pkl', 'rb'))
        data_X[:,:,i] = scaler.transform(data_X[:,:,i])
    scaler_y = load(open("models/"+ fname + "_scaler_tr_Y.pkl", 'rb'))

    #Evaluate
    preds_region = []
    for cc in range(5):
        print("Loading...", "models/"+ fname + "_" + str(cc) +'.h5')
        model = tf.keras.models.load_model("models/"+ fname + "_" + str(cc) +'.h5')
        preds = model.predict(data_X)
        preds_region.append(scaler_y.inverse_transform(preds))
        
    preds_all.append(preds_region)
    
    preds_region = np.array(preds_region).reshape(5,data_X.shape[0],data_X.shape[1])
    np.save(os.getcwd()+"/results/res_"+ fname +'.npy', preds_region)
    np.save(os.getcwd()+"/results/real_"+ fname +'.npy', data_y)
# Out:
# best_model_uci_HOSP.base
# 2020-05-01 2021-03-19
# ['uci']
# (310, 14) 31
# best_model_uci_HOSP.base_scaler_tr_X_0.pkl
# Loading... models/best_model_uci_HOSP.base_0.h5
# Loading... models/best_model_uci_HOSP.base_1.h5
# Loading... models/best_model_uci_HOSP.base_2.h5
# Loading... models/best_model_uci_HOSP.base_3.h5
# Loading... models/best_model_uci_HOSP.base_4.h5
#
# best_model_uci_HOSP.base.mov
# 2020-05-01 2021-03-19
# ['risk_BCN_7', 'risk_GI_7', 'risk_LLE_7', 'risk_TAR_7', 'uci']
# (310, 70) 31
# best_model_uci_HOSP.base.mov_scaler_tr_X_0.pkl
# best_model_uci_HOSP.base.mov_scaler_tr_X_1.pkl
# best_model_uci_HOSP.base.mov_scaler_tr_X_2.pkl
# best_model_uci_HOSP.base.mov_scaler_tr_X_3.pkl
# best_model_uci_HOSP.base.mov_scaler_tr_X_4.pkl
# Loading... models/best_model_uci_HOSP.base.mov_0.h5
# Loading... models/best_model_uci_HOSP.base.mov_1.h5
# Loading... models/best_model_uci_HOSP.base.mov_2.h5
# Loading... models/best_model_uci_HOSP.base.mov_3.h5
# Loading... models/best_model_uci_HOSP.base.mov_4.h5

# %%
THR
# Out:
# 31

# %%
# EVALUATION 
# Test: 2021-02-03

# %%
plot = False
perfAll = []
for cls in modelNames[:]:
    print()
    print(cls)

    #Preds data
    fname = cls
    real = np.load("results/real_"+ fname +'.npy')
    res = np.load("results/res_"+ fname +'.npy')
    print(res.shape,real.shape)
    pred = np.nanmean(res, axis=0)
    pred_s = np.nanstd(res, axis=0)*2
    print(real.shape,pred.shape)
    
    #Filter test
    pred = pred[-THR:,:]
    real = real[-THR:,:]
    print(real.shape,pred.shape)
    print("NAN real:", np.sum(np.isnan(real)),"NAN pred:", np.sum(np.isnan(pred)))
    
    nulls = []
    for j in [0,2,6]:        
        result = []          
        for i in range(pred.shape[0]):
            if not np.isnan(pred[i,j]) and not np.isnan(real[i,j]):
                p = pred[i,j]
                r = real[i,j]
                result.append([-999,i,j,p,r])
            else:
                nulls.append([i,j])
                
        result = np.array(result)
        
        #Daily
        mae = np.nanmean(np.abs(result[:,4]-result[:,3]))
        mape = np.nanmean(np.abs(result[:,4]-result[:,3])/(result[:,4]+1e-5))
        mae_s = np.nanstd(np.abs(result[:,4]-result[:,3]))
        mape_s = np.nanstd(np.abs(result[:,4]-result[:,3])/(result[:,4]+1e-5))            
        r2 = np.corrcoef(result[:,4].astype(float),result[:,3].astype(float))[0,1]

        #CumSum
        realAcc = np.nancumsum(result[:,4])
        predAcc = np.nancumsum(result[:,3])
        maeAcc = np.nanmean(np.abs(realAcc-predAcc))
        mapeAcc = np.nanmean(np.abs(realAcc-predAcc)/(realAcc+1e-5))
        maeAcc_s = np.nanstd(np.abs(realAcc-predAcc))
        mapeAcc_s = np.nanstd(np.abs(realAcc-predAcc)/(realAcc+1e-5))
        print(j+1, len(result), 
              "MAE:",np.round(mae,2),
              "MAPE:",np.round(mape,2),
              "CUM-MAE:",np.round(maeAcc,2),
              "CUM-MAPE:", np.round(mapeAcc,2),
              "R2:", np.round(r2,2)
             )

        if mapeAcc > 1000:
            print("ERROR!!")
            print(realAcc)
            print(predAcc)
            break

        if plot and j in [0]:
            plt.plot(result[:,3],label="pred")
            plt.plot(result[:,4],label="real")
            plt.title("Test predictions at " + str(j+1) + "day")
            plt.ylabel("# Incidence")
            plt.legend()
            plt.show()

        perfAll.append([cls,j+1,len(real), np.round(mae,2), np.round(mape,2),
                        np.round(mae_s,2), np.round(mape_s,2),
                        np.round(maeAcc,2),np.round(mapeAcc,2),
                        np.round(maeAcc_s,2),np.round(mapeAcc_s,2), 
                        np.round(r2,2)])
    
    #Performance of summing all 21 predictions during the test period
    result = []
    for i in range(pred.shape[0]):            
        p=0
        ps=0
        r=0
        dim=0 + 1e-5
        for j in range(7):
            if not np.isnan(real[i,j]) and not np.isnan(pred[i,j]):
                p += pred[i,j]
                ps += pred_s[i,j]*2
                r += real[i,j]
                dim += 1
        result.append([-999,i,p/dim,r/dim,ps/dim])
        
    result = np.array(result)

    #Daily
    mae = np.nanmean(np.abs(result[:,3]-result[:,2]))
    mape = np.nanmean(np.abs(result[:,3]-result[:,2])/(result[:,3]+1e-5))
    mae_s = np.nanstd(np.abs(result[:,3]-result[:,2]))
    mape_s = np.nanstd(np.abs(result[:,3]-result[:,2])/(result[:,3]+1e-5))        
    r2 = np.corrcoef(result[:,3].astype(float),result[:,2].astype(float))[0,1]

    #CumSum
    realAcc = np.nancumsum(result[:,3])
    predAcc = np.nancumsum(result[:,2])
    predAcc_s = np.nancumsum(result[:,4])
    maeAcc = np.nanmean(np.abs(realAcc-predAcc))
    mapeAcc = np.nanmean(np.abs(realAcc-predAcc)/(realAcc+1e-5))
    maeAcc_s = np.nanstd(np.abs(realAcc-predAcc))
    mapeAcc_s = np.nanstd(np.abs(realAcc-predAcc)/(realAcc+1e-5))
    perfAll.append([cls,-1,len(real), np.round(mae,2), np.round(mape,2),
                    np.round(mae_s,2), np.round(mape_s,2),
                    np.round(maeAcc,2),np.round(mapeAcc,2),
                    np.round(maeAcc_s,2),np.round(mapeAcc_s,2),np.round(r2,2)]) 

    print("ALL", len(result), 
          "MAE:",np.round(mae,2),
          "MAPE:",np.round(mape,2),
          "CUM-MAE:",np.round(maeAcc,2),
          "CUM-MAPE:", np.round(mapeAcc,2),
          "R2:", np.round(r2,2)
         ) 

    #Results
    plt.errorbar(x=range(len(result)),y=result[:,2],label="pred",yerr=result[:,4])
    x=range(len(result))
    y=result[:,2].astype(float)
    y[np.isnan(y)]=0
    error=result[:,4].astype(float)
    error[np.isnan(error)]=0
    plt.fill_between(x, y-error, y+error,alpha=0.3)    
    plt.plot(result[:,3],label="real", linestyle='dashed', marker='o')
    plt.title("Test predictions using ALL criteria")
    plt.ylabel("# Hospitalization")
    plt.ylim(0,400)
    plt.legend()
    plt.show()
    
    plt.errorbar(x=range(len(predAcc_s)),y=result[:,2].cumsum(),label="pred",yerr=predAcc_s) #, linestyle='dashed', marker='.'
    x=range(len(predAcc_s))
    y=result[:,2].cumsum().astype(float)
    y[np.isnan(y)]=0
    error=predAcc_s.astype(float)
    error[np.isnan(error)]=0
    plt.fill_between(x, y-error, y+error,alpha=0.3)     
    plt.plot(result[:,3].cumsum(),label="real", linestyle='dashed', marker='o')
    plt.title("Cumsum test predictions using ALL criteria")
    plt.ylabel("# ICU occupancy")
    plt.ylim(0,5000)
    plt.legend()    
    plt.show()

dfPerf = pd.DataFrame(perfAll, columns=["cls","dayPred","num","mae","mape","mae_s","mape_s",
                                        "maeAcc","mapeAcc","maeAcc_s","mapeAcc_s","r2"])

dfPerf[["cls","dayPred","mae","mape","maeAcc","maeAcc_s","mapeAcc","mapeAcc_s","r2"]]
# Out:
# best_model_uci_HOSP.base
# (5, 310, 7) (310, 7)
# (310, 7) (310, 7)
# (31, 7) (31, 7)
# NAN real: 0 NAN pred: 0
# 1 31 MAE: 16.53 MAPE: 0.27 CUM-MAE: 155.44 CUM-MAPE: 0.12 R2: 0.28
# 3 31 MAE: 18.61 MAPE: 0.34 CUM-MAE: 260.13 CUM-MAPE: 0.25 R2: 0.09
# 7 31 MAE: 23.44 MAPE: 0.42 CUM-MAE: 348.65 CUM-MAPE: 0.32 R2: 0.24
# ALL 31 MAE: 17.03 MAPE: 0.25 CUM-MAE: 266.69 CUM-MAPE: 0.24 R2: 0.37
# best_model_uci_HOSP.base.mov
# (5, 310, 7) (310, 7)
# (310, 7) (310, 7)
# (31, 7) (31, 7)
# NAN real: 0 NAN pred: 0
# 1 31 MAE: 13.43 MAPE: 0.21 CUM-MAE: 20.17 CUM-MAPE: 0.04 R2: 0.37
# 3 31 MAE: 15.76 MAPE: 0.29 CUM-MAE: 180.05 CUM-MAPE: 0.17 R2: 0.09
# 7 31 MAE: 22.08 MAPE: 0.4 CUM-MAE: 343.75 CUM-MAPE: 0.31 R2: 0.32
# ALL 31 MAE: 12.29 MAPE: 0.18 CUM-MAE: 191.46 CUM-MAPE: 0.16 R2: 0.51
#                             cls  dayPred    mae  mape  maeAcc  maeAcc_s  \
# 0      best_model_uci_HOSP.base        1  16.53  0.27  155.44     85.59
# 1      best_model_uci_HOSP.base        3  18.61  0.34  260.13    115.78
# 2      best_model_uci_HOSP.base        7  23.44  0.42  348.65    178.92
# 3      best_model_uci_HOSP.base       -1  17.03  0.25  266.69    132.22
# 4  best_model_uci_HOSP.base.mov        1  13.43  0.21   20.17     13.15
# 5  best_model_uci_HOSP.base.mov        3  15.76  0.29  180.05     83.90
# 6  best_model_uci_HOSP.base.mov        7  22.08  0.40  343.75    178.66
# 7  best_model_uci_HOSP.base.mov       -1  12.29  0.18  191.46     96.98
#
#    mapeAcc  mapeAcc_s    r2
# 0     0.12       0.03  0.28
# 1     0.25       0.07  0.09
# 2     0.32       0.06  0.24
# 3     0.24       0.03  0.37
# 4     0.04       0.06  0.37
# 5     0.17       0.05  0.09
# 6     0.31       0.05  0.32
# 7     0.16       0.03  0.51

# %%
#R2 std
plot = True
r2All = []
for cls in modelNames:
    print()
    print(cls)

    #Preds data
    fname = cls
    real = np.load("results/real_"+ fname +'.npy')
    res = np.load("results/res_"+ fname +'.npy')
    print(res.shape,real.shape)

    
    nulls = []
    for k in range(res.shape[0]):
        pred = res[k]
        
        #Filter test
        pred = pred[-THR:,:]
        real = real[-THR:,:]

        for j in [0,2,6]:        
            result = []          
            for i in range(pred.shape[0]):
                if not np.isnan(pred[i,j]) and not np.isnan(real[i,j]):
                    p = pred[i,j]
                    r = real[i,j]
                    result.append([-999,i,j,p,r])
                else:
                    nulls.append([i,j])
            result = np.array(result)

            #Daily          
            r2 = np.corrcoef(result[:,4].astype(float),result[:,3].astype(float))[0,1]
            r2All.append([cls,j+1,len(real), np.round(r2,2)])

        #Performance of summing all 21 predictions during the test period
        result = []
        for i in range(pred.shape[0]):            
            p=0
            r=0
            dim=0 + 1e-5
            for j in range(7):
                if not np.isnan(real[i,j]) and not np.isnan(pred[i,j]):
                    p += pred[i,j]
                    r += real[i,j]
                    dim += 1
            result.append([-999,i,p/dim,r/dim])

        result = np.array(result)

        #Daily       
        r2 = np.corrcoef(result[:,3].astype(float),result[:,2].astype(float))[0,1]
        r2All.append([cls,-1,len(real), np.round(r2,2)]) 

r2All = pd.DataFrame(r2All,columns=["cls","dayPred","len","r2"])
grp1 = r2All.groupby(["cls","dayPred","len"]).agg(["mean","std"]).reset_index()
grp1
# Out:
# best_model_uci_HOSP.base
# (5, 310, 7) (310, 7)
#
# best_model_uci_HOSP.base.mov
# (5, 310, 7) (310, 7)
#                             cls dayPred len     r2
#                                               mean       std
# 0      best_model_uci_HOSP.base      -1  31  0.372  0.037683
# 1      best_model_uci_HOSP.base       1  31  0.282  0.027749
# 2      best_model_uci_HOSP.base       3  31  0.094  0.027019
# 3      best_model_uci_HOSP.base       7  31  0.240  0.025495
# 4  best_model_uci_HOSP.base.mov      -1  31  0.492  0.065727
# 5  best_model_uci_HOSP.base.mov       1  31  0.350  0.091378
# 6  best_model_uci_HOSP.base.mov       3  31  0.064  0.077653
# 7  best_model_uci_HOSP.base.mov       7  31  0.312  0.038987

# %%
grp = dfPerf[["cls","dayPred","r2"]].groupby(["cls","dayPred"]).agg(["mean","std"]).reset_index()
grp["r2_m"] = grp["r2"]["mean"]
grp["r2_m"] = grp["r2_m"].astype(float)
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="r2_m")
display(pvt)
display(pvt.mean(axis=1).round(2))
display(pvt.std(axis=1).round(2))
# Out:
# dayPred                         -1     1     3     7
# cls
# best_model_uci_HOSP.base      0.37  0.28  0.09  0.24
# best_model_uci_HOSP.base.mov  0.51  0.37  0.09  0.32
# cls
# best_model_uci_HOSP.base        0.24
# best_model_uci_HOSP.base.mov    0.32
# dtype: float64
# cls
# best_model_uci_HOSP.base        0.12
# best_model_uci_HOSP.base.mov    0.17
# dtype: float64

# %%
y = pd.DataFrame(pvt.T.reset_index(drop=False))
y["LSTM"]= y["best_model_uci_HOSP.base"]
y["LSTM.mov"]= y["best_model_uci_HOSP.base.mov"]
yAll = y[y["dayPred"]==-1]
y1 = y[y["dayPred"]==1]
y3 = y[y["dayPred"]==3]
y7 = y[y["dayPred"]==7]

yAll = yAll[["LSTM","LSTM.mov"]].T[0].values
y1 = y1[["LSTM","LSTM.mov"]].T[1].values
y3 = y3[["LSTM","LSTM.mov"]].T[2].values
y7 = y7[["LSTM","LSTM.mov"]].T[3].values
display(yAll)

error = grp1
error["LSTM"]= error["cls"]=="best_model_uci_HOSP.base"
error["LSTM.mov"]= error["cls"]=="best_model_uci_HOSP.base.mov"

errorAll = error[error["dayPred"]==-1]
error1 = error[error["dayPred"]==1]
error3 = error[error["dayPred"]==3]
error7 = error[error["dayPred"]==7]

errorAll = errorAll["r2"]["std"].values
error1 = error1["r2"]["std"].values
error3 = error3["r2"]["std"].values
error7 = error7["r2"]["std"].values
display(errorAll)

plt.figure(figsize=(9,6))
plt.errorbar(range(len(yAll)), yAll, errorAll/2., label="All", linestyle='-', marker='o', linewidth=3)
plt.errorbar(range(len(y1)), y1, error1/2., label="At 1 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)
plt.errorbar(range(len(y3)), y3, error3/2., label="At 3 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)
plt.errorbar(range(len(y7)), y7, error7/2., label="At 7 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)

plt.xticks(range(len(yAll)),["LSTM","LSTM.mov"])
plt.ylim(-0.1,1.15)
plt.legend(loc="upper left")
plt.grid(axis='y')
plt.show()
# Out:
# array([0.37, 0.51])
# array([0.03768289, 0.06572671])

# %%
grp = dfPerf[["cls","dayPred","mae","mae_s"]].groupby(["cls","dayPred"]).agg(["mean","std"]).reset_index()
grp["mae_m"] = grp["mae"]["mean"]
grp["mae_m"] = grp["mae_m"].astype(float)
grp["mae_ss"] = grp["mae_s"]["mean"]
grp["mae_ss"] = grp["mae_ss"].astype(float)
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mae_m")
display(pvt)
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mae_ss")
display(pvt)
display(pvt.mean(axis=1).round(2))
display(pvt.std(axis=1).round(2))
# Out:
# dayPred                          -1      1      3      7
# cls
# best_model_uci_HOSP.base      17.03  16.53  18.61  23.44
# best_model_uci_HOSP.base.mov  12.29  13.43  15.76  22.08
# dayPred                         -1      1      3      7
# cls
# best_model_uci_HOSP.base      9.16  12.37  13.81  14.87
# best_model_uci_HOSP.base.mov  6.91  10.43  12.15  13.63
# cls
# best_model_uci_HOSP.base        12.55
# best_model_uci_HOSP.base.mov    10.78
# dtype: float64
# cls
# best_model_uci_HOSP.base        2.48
# best_model_uci_HOSP.base.mov    2.89
# dtype: float64

# %%
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mae_m")
y = pd.DataFrame(pvt.T.reset_index(drop=False))
y["LSTM"]= y["best_model_uci_HOSP.base"]
y["LSTM.mov"]= y["best_model_uci_HOSP.base.mov"]
yAll = y[y["dayPred"]==-1]
y1 = y[y["dayPred"]==1]
y3 = y[y["dayPred"]==3]
y7 = y[y["dayPred"]==7]

yAll = yAll[["LSTM","LSTM.mov"]].T[0].values
y1 = y1[["LSTM","LSTM.mov"]].T[1].values
y3 = y3[["LSTM","LSTM.mov"]].T[2].values
y7 = y7[["LSTM","LSTM.mov"]].T[3].values
display(yAll)

pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mae_ss")
error = pd.DataFrame(pvt.T.reset_index(drop=False))
error["LSTM"]= error["best_model_uci_HOSP.base"]
error["LSTM.mov"]= error["best_model_uci_HOSP.base.mov"]

errorAll = error[error["dayPred"]==-1]
error1 = error[error["dayPred"]==1]
error3 = error[error["dayPred"]==3]
error7 = error[error["dayPred"]==7]

errorAll = errorAll[["LSTM","LSTM.mov"]].T[0].values
error1 = error1[["LSTM","LSTM.mov"]].T[1].values
error3 = error3[["LSTM","LSTM.mov"]].T[2].values
error7 = error7[["LSTM","LSTM.mov"]].T[3].values
display(errorAll)

plt.figure(figsize=(9,6))
plt.errorbar(range(len(yAll)), yAll, errorAll/2., label="All", linestyle='-', marker='o', linewidth=3)
plt.errorbar(range(len(y1)), y1, error1/2., label="At 1 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)
plt.errorbar(range(len(y3)), y3, error3/2., label="At 3 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)
plt.errorbar(range(len(y7)), y7, error7/2., label="At 7 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)

plt.xticks(range(len(yAll)),["LSTM","LSTM.mov"])
plt.legend(loc="upper left")
plt.grid(axis='y')
plt.show()
# Out:
# array([17.03, 12.29])
# array([9.16, 6.91])

# %%
grp = dfPerf[["cls","dayPred","mape","mape_s"]].groupby(["cls","dayPred"]).agg(["mean","std"]).reset_index()
grp["mape_m"] = grp["mape"]["mean"]
grp["mape_m"] = grp["mape_m"].astype(float)
grp["mape_ss"] = grp["mape_s"]["mean"]
grp["mape_ss"] = grp["mape_ss"].astype(float)
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mape_m")
display(pvt)
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mape_ss")
display(pvt)
display(pvt.mean(axis=1).round(2))
display(pvt.std(axis=1).round(2))
# Out:
# dayPred                         -1     1     3     7
# cls
# best_model_uci_HOSP.base      0.25  0.27  0.34  0.42
# best_model_uci_HOSP.base.mov  0.18  0.21  0.29  0.40
# dayPred                         -1     1     3     7
# cls
# best_model_uci_HOSP.base      0.15  0.29  0.36  0.38
# best_model_uci_HOSP.base.mov  0.11  0.21  0.32  0.36
# cls
# best_model_uci_HOSP.base        0.30
# best_model_uci_HOSP.base.mov    0.25
# dtype: float64
# cls
# best_model_uci_HOSP.base        0.10
# best_model_uci_HOSP.base.mov    0.11
# dtype: float64

# %%
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mape_m")
y = pd.DataFrame(pvt.T.reset_index(drop=False))
y["LSTM"]= y["best_model_uci_HOSP.base"]
y["LSTM.mov"]= y["best_model_uci_HOSP.base.mov"]
yAll = y[y["dayPred"]==-1]
y1 = y[y["dayPred"]==1]
y3 = y[y["dayPred"]==3]
y7 = y[y["dayPred"]==7]

yAll = yAll[["LSTM","LSTM.mov"]].T[0].values
y1 = y1[["LSTM","LSTM.mov"]].T[1].values
y3 = y3[["LSTM","LSTM.mov"]].T[2].values
y7 = y7[["LSTM","LSTM.mov"]].T[3].values
display(yAll)

pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mape_ss")
error = pd.DataFrame(pvt.T.reset_index(drop=False))
error["LSTM"]= error["best_model_uci_HOSP.base"]
error["LSTM.mov"]= error["best_model_uci_HOSP.base.mov"]

errorAll = error[error["dayPred"]==-1]
error1 = error[error["dayPred"]==1]
error3 = error[error["dayPred"]==3]
error7 = error[error["dayPred"]==7]

errorAll = errorAll[["LSTM","LSTM.mov"]].T[0].values
error1 = error1[["LSTM","LSTM.mov"]].T[1].values
error3 = error3[["LSTM","LSTM.mov"]].T[2].values
error7 = error7[["LSTM","LSTM.mov"]].T[3].values
display(errorAll)

plt.figure(figsize=(9,6))
plt.errorbar(range(len(yAll)), yAll, errorAll/2., label="All", linestyle='-', marker='o', linewidth=3)
plt.errorbar(range(len(y1)), y1, error1/2., label="At 1 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)
plt.errorbar(range(len(y3)), y3, error3/2., label="At 3 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)
plt.errorbar(range(len(y7)), y7, error7/2., label="At 7 day", linestyle='--', marker='o', linewidth=2,alpha=0.5)

plt.xticks(range(len(yAll)),["LSTM","LSTM.mov"])
plt.legend(loc="upper left")
plt.grid(axis='y')
plt.show()
# Out:
# array([0.25, 0.18])
# array([0.15, 0.11])

# %%
pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mape_m")
y = pd.DataFrame(pvt.T.reset_index(drop=False))
y["LSTM"]= y["best_model_uci_HOSP.base"]
y["LSTM.mov"]= y["best_model_uci_HOSP.base.mov"]
yAll = y[y["dayPred"]==-1]
yAll = yAll[["LSTM","LSTM.mov"]].T[0].values
display(yAll)

pvt = pd.pivot(grp, index=["cls"],columns="dayPred",values="mape_ss")
error = pd.DataFrame(pvt.T.reset_index(drop=False))
error["LSTM"]= error["best_model_uci_HOSP.base"]
error["LSTM.mov"]= error["best_model_uci_HOSP.base.mov"]

errorAll = error[error["dayPred"]==-1]
errorAll = errorAll[["LSTM","LSTM.mov"]].T[0].values
display(errorAll)

plt.figure(figsize=(5,5))
plt.errorbar(range(len(yAll)), yAll, yerr=errorAll/2., label="ICU", linestyle='-', marker='o', 
             linewidth=3, c="red", alpha=0.5)
plt.xticks(range(len(yAll)),["LSTM","LSTM.mov"])
plt.yticks([0.1*i for i in range(1,11)])
plt.legend(loc="upper left")
plt.grid(axis='y')
plt.ylim(0,1)
plt.title("MAPE results with all criteria (Regional)")
plt.show()
# Out:
# array([0.25, 0.18])
# array([0.15, 0.11])
